# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import Counter
import json

import math
import statistics

# %% [markdown]
# # Upload Datasets

# %%
Data_File1 = pd.read_csv (r'/homedir01/eeldeeb19/Oulu Data/sc-export-2021022500-elsys.csv')

# %%
Data_File1.head()
# Out:
#             time                   deveui  temperature  humidity  light  \
# 0  1596240002191  a8-17-58-ff-fe-04-64-6b         21.4      44.0    0.0
# 1  1596240006323  a8-17-58-ff-fe-04-63-af         21.5      46.0    0.0
# 2  1596240010305  a8-17-58-ff-fe-04-63-b0         21.5      47.0    0.0
# 3  1596240012968  a8-17-58-ff-fe-03-0f-71         21.5      45.0    0.0
# 4  1596240013257  a8-17-58-ff-fe-03-10-45         21.5      47.0    0.0
#
#    motion    co2  battery  sound_avg  sound_peak  moisture  pressure  \
# 0    79.0    NaN    3.635       34.0        64.0       NaN       NaN
# 1    86.0    NaN    3.638       34.0        64.0       NaN       NaN
# 2    76.0    NaN    3.638       34.0        64.0       NaN       NaN
# 3     5.0  500.0    3.684        NaN         NaN       NaN       NaN
# 4     5.0  479.0    3.686        NaN         NaN       NaN       NaN
#
#    acceleration_x  acceleration_y  acceleration_z
# 0             NaN             NaN             NaN
# ...

# %%
len(Data_File1)
# Out:
# 6957973

# %% [markdown]
# In the first dataset, we have 6957973 readings for all the devices. Each device is attached to a unique id called deveui. The physical parameters measured are temperature, humidity, light, motion, CO2, battery, sound average, sound peak, moisture, and pressure. For the acceleration, there are no data provided.

# %% [markdown]
# In this file, we will do an overall analysis for all parameters, then visualize each parameter over time for each specific device.

# %% [markdown]
# # overall analysis

# %% [markdown]
# In this section, all readings for all parameters are visualized over time for all sensors.

# %%
Co2_1 = Data_File1["co2"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Co2_1[0:6957973])
plt.title('Co2')
plt.xlabel('Samples')
plt.ylabel('Co2 readings')
# plt.savefig('Co2_1.jpg')
plt.show()


Battery_1 = Data_File1["battery"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Battery_1[0:6957973])
plt.title('Battery')
plt.xlabel('Samples')
plt.ylabel('Battery readings')
# plt.savefig('Battery_1.jpg')
plt.show()


Temperature_1 = Data_File1["temperature"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Temperature_1[0:6957973])
plt.title('Temperature')
plt.xlabel('Samples')
plt.ylabel('Temperature readings')
# plt.savefig('Temperature_1.jpg')
plt.show()


Humidity_1 = Data_File1["humidity"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Humidity_1[0:6957973])
plt.title('Humidity')
plt.xlabel('Samples')
plt.ylabel('Humidity readings')
# plt.savefig('Humidity_1.jpg')
plt.show()


Light_1 = Data_File1["light"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Light_1[0:6957973])
plt.title('Light')
plt.xlabel('Samples')
plt.ylabel('Light readings')
# plt.savefig('Light_1.jpg')
plt.show()


Sound_avg_1 = Data_File1["sound_avg"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Sound_avg_1[0:6957973])
plt.title('Sound_avg')
plt.xlabel('Samples')
plt.ylabel('Sound_avg readings')
# plt.savefig('Sound_avg_1.jpg')
plt.show()


Sound_peak_1 = Data_File1["sound_peak"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Sound_peak_1[0:6957973])
plt.title('Sound_peak')
plt.xlabel('Samples')
plt.ylabel('Sound_peak readings')
# plt.savefig('Sound_peak_1.jpg')
plt.show()


Motion_1 = Data_File1["motion"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Motion_1[0:6957973])
plt.title('Motion')
plt.xlabel('Samples')
plt.ylabel('Motion readings')
# plt.savefig('Motion_1.jpg')
plt.show()


Pressure_1 = Data_File1["pressure"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Pressure_1[0:6957973])
plt.title('Pressure')
plt.xlabel('Samples')
plt.ylabel('Pressure readings')
# plt.savefig('Pressure_1.jpg')
plt.show()


Moisture_1 = Data_File1["moisture"]
# t = Data_File1["time"]/1e18
t = list(range(1, 6957974))
plt.plot(t,Moisture_1[0:6957973])
plt.title('Moisture')
plt.xlabel('Samples')
plt.ylabel('Moisture readings')
# plt.savefig('Moisture_1.jpg')
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Analysis per device

# %%
Deveui = Data_File1["deveui"]
Devices = dict(Counter(Deveui))
len(Devices)
# print(a)
# Out:
# 468

# %% [markdown]
# There are 468 diffferent devices in the first dataset. If we remember the number of devices provided in the documentation, it was 431, which means that we have 37 un-documented devices.

# %%
Rep = Devices.values()
print(Rep)
# Out:
# dict_values([15588, 13665, 14514, 15400, 11645, 15150, 13894, 15066, 14585, 15200, 15703, 14117, 14905, 15163, 15359, 15878, 15143, 14904, 15604, 15061, 12698, 14954, 15727, 14622, 13497, 14976, 15174, 14799, 15103, 15034, 15419, 15071, 14201, 13836, 15067, 15165, 12795, 98559, 14413, 15012, 15236, 15396, 15508, 14338, 14938, 15389, 13592, 58036, 14592, 13764, 14977, 15843, 15022, 15460, 15743, 14461, 15284, 14761, 15165, 14248, 15015, 15485, 14333, 15354, 15527, 15265, 12470, 15112, 15103, 15549, 15263, 15248, 15154, 14757, 15434, 1921, 14537, 14845, 14707, 15064, 14184, 15271, 15752, 15361, 15690, 15417, 14590, 15095, 15288, 15089, 13305, 13538, 15269, 15239, 14670, 13242, 15130, 15556, 15486, 15554, 15272, 13055, 15334, 15003, 15229, 14522, 15059, 15641, 14627, 15263, 15684, 15720, 15045, 15081, 15308, 15279, 12973, 13807, 13192, 12498, 15831, 15345, 15545, 15450, 15125, 14902, 15313, 14914, 8349, 14684, 15809, 15761, 15149, 15604, 15415, 15171, 14937, 14546, 15633, 14595, 14909, 
# ...

# %%
SORTED_REP = sorted(Rep)
print(SORTED_REP[0:3])
print(SORTED_REP[-3:][::-1])
print(statistics.mean(Rep))
# Out:
# [2, 211, 218]
# [122561, 98559, 65434]
# 14867.463675213676

# %% [markdown]
# Here, we are counting the number of repetition of each unique ID in the dataset. This means that we count the number of collected measurements per device.
#
# The minimum number of collected measurements for a devices are [2, 211, 218, ...], whearas the The maximum number of collected measurements for a devices are [122561, 98559, 65434, ...]. The mean of collected measurements for each sensor is 14867.463675213676 measurements per sensor.

# %%
Devices_Headers = list(Devices.keys())
Deveui_lis = list(Deveui)

# %% [markdown]
# Here, we save the unique IDs in a list. To find the position of a certain ID, for example, "a8-17-58-ff-fe-04-1f-ee", we run the next line:

# %%
Devices_Headers.index("a8-17-58-ff-fe-04-1f-ee")
# Out:
# 452

# %% [markdown]
# It is located at position 452 in the list.

# %% [markdown]
# #

# %% [markdown]
# Next, we will visualize the measured parameters for each device and plot some examples.

# %%
all_list = []
for i in range (0,len(Devices_Headers)) :
    res_list = []
    for j in range (0,len(Deveui_lis)) :
        if Deveui_lis[j] == Devices_Headers[i] : 
            res_list.append(j)
    all_list .append(res_list)
#print(Deveui_lis.index(it[256]))
print(all_list)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# # Device 28

# %%
Devices_Headers[28]
# Out:
# 'a8-17-58-ff-fe-04-64-32'

# %%
len(all_list[28])
# Out:
# 15103

# %%
Co2_d28 = Data_File1["co2"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Co2_d28[t])
plt.title('Co2')
plt.xlabel('Samples')
plt.ylabel('Co2 readings for device 28')
# plt.savefig('Co2_d28.jpg')
plt.show()


Battery_d28 = Data_File1["battery"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Battery_d28[t])
plt.title('Battery')
plt.xlabel('Samples')
plt.ylabel('Battery readings for device 28')
# plt.savefig('Battery_d28.jpg')
plt.show()


Temperature_d28 = Data_File1["temperature"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Temperature_d28[t])
plt.title('Temperature')
plt.xlabel('Samples')
plt.ylabel('Temperature readings for device 28')
# plt.savefig('Temperature_d28.jpg')
plt.show()


Humidity_d28 = Data_File1["humidity"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Humidity_d28[t])
plt.title('Humidity')
plt.xlabel('Samples')
plt.ylabel('Humidity readings for device 28')
# plt.savefig('Humidity_d28.jpg')
plt.show()


Light_d28 = Data_File1["light"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Light_d28[t])
plt.title('Light')
plt.xlabel('Samples')
plt.ylabel('Light readings for device 28')
# plt.savefig('Light_d28.jpg')
plt.show()


Sound_avg_d28 = Data_File1["sound_avg"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Sound_avg_d28[t])
plt.title('Sound_avg')
plt.xlabel('Samples')
plt.ylabel('Sound_avg readings for device 28')
# plt.savefig('Sound_avg_d28.jpg')
plt.show()


Sound_peak_d28 = Data_File1["sound_peak"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Sound_peak_d28[t])
plt.title('Sound_peak')
plt.xlabel('Samples')
plt.ylabel('Sound_peak readings for device 28')
# plt.savefig('Sound_peak_d28.jpg')
plt.show()


Motion_d28 = Data_File1["motion"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Motion_d28[t])
plt.title('Motion')
plt.xlabel('Samples')
plt.ylabel('Motion readings for device 28')
# plt.savefig('Motion_d28.jpg')
plt.show()


Pressure_d28 = Data_File1["pressure"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Pressure_d28[t])
plt.title('Pressure')
plt.xlabel('Samples')
plt.ylabel('Pressure readings for device 28')
# plt.savefig('Pressure_d28.jpg')
plt.show()


Moisture_d28 = Data_File1["moisture"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[28]
plt.plot(t,Moisture_d28[t])
plt.title('Moisture')
plt.xlabel('Samples')
plt.ylabel('Moisture readings for device 28')
# plt.savefig('Moisture_d28.jpg')
plt.show()

# %% [markdown]
# The previous plots are the physical parameters measured over the whole dataset for device 28 with the ID 'a8-17-58-ff-fe-04-64-32'. This device has 15103 recorded readings in the dataset. Its type is sound device, that is why it has collected records for sound average, sound peak motion, and light, while it has sparse list for CO2, pressure, and moisture.

# %% [markdown]
# #

# %% [markdown]
# # Device 3

# %%
Devices_Headers[3]
# Out:
# 'a8-17-58-ff-fe-03-0f-71'

# %%
len(all_list[3])
# Out:
# 15400

# %%
Co2_d3 = Data_File1["co2"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Co2_d3[t])
plt.title('Co2')
plt.xlabel('Samples')
plt.ylabel('Co2 readings for device 3')
# plt.savefig('Co2_d3.jpg')
plt.show()


Battery_d3 = Data_File1["battery"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Battery_d3[t])
plt.title('Battery')
plt.xlabel('Samples')
plt.ylabel('Battery readings for device 3')
# plt.savefig('Battery_d3.jpg')
plt.show()


Temperature_d3 = Data_File1["temperature"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Temperature_d3[t])
plt.title('Temperature')
plt.xlabel('Samples')
plt.ylabel('Temperature readings for device 3')
# plt.savefig('Temperature_d3.jpg')
plt.show()


Humidity_d3 = Data_File1["humidity"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Humidity_d3[t])
plt.title('Humidity')
plt.xlabel('Samples')
plt.ylabel('Humidity readings for device 3')
# plt.savefig('Humidity_d3.jpg')
plt.show()


Light_d3 = Data_File1["light"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Light_d3[t])
plt.title('Light')
plt.xlabel('Samples')
plt.ylabel('Light readings for device 3')
# plt.savefig('Light_d3.jpg')
plt.show()


Sound_avg_d3 = Data_File1["sound_avg"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Sound_avg_d3[t])
plt.title('Sound_avg')
plt.xlabel('Samples')
plt.ylabel('Sound_avg readings for device 3')
# plt.savefig('Sound_avg_d3.jpg')
plt.show()


Sound_peak_d3 = Data_File1["sound_peak"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Sound_peak_d3[t])
plt.title('Sound_peak')
plt.xlabel('Samples')
plt.ylabel('Sound_peak readings for device 3')
# plt.savefig('Sound_peak_d3.jpg')
plt.show()


Motion_d3 = Data_File1["motion"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Motion_d3[t])
plt.title('Motion')
plt.xlabel('Samples')
plt.ylabel('Motion readings for device 3')
# plt.savefig('Motion_d3.jpg')
plt.show()


Pressure_d3 = Data_File1["pressure"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Pressure_d3[t])
plt.title('Pressure')
plt.xlabel('Samples')
plt.ylabel('Pressure readings for device 3')
# plt.savefig('Pressure_d3.jpg')
plt.show()


Moisture_d3 = Data_File1["moisture"]
#len_time =  len(all_list[0])
# t = Data_File1["time"]/1e18
#t = list(range(1, len_time))
t = all_list[3]
plt.plot(t,Moisture_d3[t])
plt.title('Moisture')
plt.xlabel('Samples')
plt.ylabel('Moisture readings for device 3')
# plt.savefig('Moisture_d3.jpg')
plt.show()

# %% [markdown]
# The previous plots are the physical parameters measured over the whole dataset for device 3 with the ID 'a8-17-58-ff-fe-03-0f-71'. This device has 15400 recorded readings in the dataset. Its type is CO2 device, that is why it has collected records for CO2, motion, and light, while it has a sparse list for sound average, sound peak, pressure, and moisture.

# %% [markdown]
# #
